# %%
import matplotlib
from datascience import *
from prob140 import *
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('fivethirtyeight')

# %%
# This is a FiniteDistribution object.

binom_vals = np.arange(3)
binom_probs = make_array(0.25, 0.5, .25)
heads_2 = FiniteDistribution().domain(binom_vals).probability(binom_probs)
heads_2
# Out:
# Domain | Probability
# 0      | 0.25
# 1      | 0.5
# 2      | 0.25

# %%
# This is a Table which looks exactly the same as above,
# (except it has a better column heading)
# which is confusing.

heads_2_table = Table().with_columns(
   'Value', binom_vals,
    'Probability', binom_probs
)
heads_2_table
# Out:
# Value | Probability
# 0     | 0.25
# 1     | 0.5
# 2     | 0.25

# %% [markdown]
# ### Distribution needs to be in a Table. ###
# We're going to want to work with it in various ways, and Table already has the computational tools we need though not the graphics.
#
# It would be better just to create Table methods and not have students distracted by a new class. Remember that we want as little discussion about the computing as possible.

# %%
# Best would be if heads_2 were a table
# and the method were a Table method called plot_dist
heads_2.plot_dist()

# %%
# Same comment as above;
# also please fix axes and bring back axis labels
same = make_array(0, 2)
heads_2.plot_event(same)

# %%
# Good
heads_2.prob_event(same)
# Out:
# 0.5

# %%
# Very good
heads_2.prob_event(make_array(2, 7))
# Out:
# 0.25

# %%
# Should be a table
heads_2.event(same)
# Out:
# Domain | Probability
# 0      | 0.25
# 2      | 0.25

# %%
type(heads_2.event(same))
# Out:
# prob140.FiniteDistribution

# %%
from prob140_tables import *

# %%
x = Table().domain([1,2,10]).probability([0.2, 0.5, 0.3])

# %%
x
# Out:
# Domain | Probability
# 1      | 0.2
# 2      | 0.5
# 10     | 0.3

# %%
x.plot_dist()

# %%
type(x)
# Out:
# datascience.tables.Table

# %%
type(x.event([1,2]))
# Out:
# datascience.tables.Table

# %%
heads_2
# Out:
# Domain | Probability
# 0      | 0.25
# 1      | 0.5
# 2      | 0.25

# %%
heads_2.apply(lambda x:2*x, "Domain")
# Out:
# array([0, 2, 4])

# %%
heads_2.append_column("Domain", heads_2.apply(lambda x:2*x, "Domain"))

# %%
heads_2
# Out:
# Domain | Probability
# 0      | 0.25
# 2      | 0.5
# 4      | 0.25
