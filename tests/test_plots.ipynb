# %%
import matplotlib.pyplot
matplotlib.pyplot.style.use('fivethirtyeight')

from prob140.plots import *
# %matplotlib inline

# %%
import prob140
prob140.__version__
# Out:
# '0.3.1.0'

# %%
# The parameters left_end, right_end, tails, and CDF should work
# for all distributions
Plot_norm(x_limits=(-2, 2), mu=0, sigma=1, left_end=-1)

# %%
# names are optional for x_limits and dist parameters
Plot_norm((-2, 2), 0, 1, left_end=-1, right_end=1)

# %%
Plot_norm((-2, 2), 0, 1, left_end=-1, right_end=1, tails=True)

# %%
Plot_norm((-2, 2), 0, 1, cdf=True)

# %% [markdown]
# All the distributions

# %%
# I could also add paramters for loc and scale
Plot_arcsine(x_limits=(0.01, 0.99))

# %%
Plot_beta(x_limits=(0, 1), a=2, b=2)

# %%
# I could also put in x0 for location and gamma for scale
Plot_cauchy(x_limits=(-5, 5))

# %%
Plot_chi2(x_limits=(0, 8), df=3)

# %%
Plot_erlang(x_limits=(0, 12), r=3, lamb=0.5)

# %%
Plot_expon(x_limits=(0, 5), lamb=1)

# %%
Plot_f(x_limits=(0.01, 5), dfn=5, dfd=2)

# %%
Plot_gamma(x_limits=(0, 20), r=5, lamb=0.5)

# %%
Plot_lognorm(x_limits=(0, 5), mu=0, sigma=0.25)

# %%
Plot_norm(x_limits=(-3, 3), mu=0, sigma=1)

# %%
Plot_rayleigh(x_limits=(0, 10), sigma=2)

# %%
Plot_pareto(x_limits=(0, 5), alpha=3)

# %%
Plot_powerlaw(x_limits=(0, 1), a=1.6)

# %%
Plot_t(x_limits=(-3, 3), df=2)

# %%
# parametrized according to https://en.wikipedia.org/wiki/Triangular_distribution
Plot_triang(x_limits=(0, 10), a=2, b=10, c=3)

# %%
# parametrized as a and b
Plot_uniform(x_limits=(0, 5), a=2, b=4)

# %%
from scipy.stats import multivariate_normal

normal = multivariate_normal(mean=[0, 0], cov=0.5)

# %%
Plot_3d((-2, 2), (-2, 2), lambda x, y: normal.pdf([x, y]))
