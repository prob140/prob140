# %%
import matplotlib.pyplot as plt
import numpy as np

from prob140 import Table, Plot, Plots

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
dist1 = Table().values([2, 3, 4]).probability([0.25, 0.5, 0.25])
Plot(dist1)

# %%
Plot(dist1, event=[3])

# %%
Plots('dist1', dist1)
