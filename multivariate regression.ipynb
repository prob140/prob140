# %%
from prob140 import *
import numpy as np
# %matplotlib inline

# %%
import prob140
prob140.__version__
# Out:
# '0.3.5.1'

# %%
multivariate_normal_regression([0, 0, 0], cov=np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]]))
